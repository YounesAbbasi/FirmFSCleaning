# %%
import pandas as pd
import numpy as np
from persiantools import characters, digits
import jdatetime
import re
from glob import glob
import os

# %%
nemad = pd.read_excel(r'C:\Users\cmos\Desktop\all_nemad2.xlsx')

# %%
def file_path(path):
    if __name__ == "__main__":
        balance_sheet = []
        profit_loss = []
        for (root, dirs, files) in os.walk(path , topdown = True):
            if len(files) == 0:
                continue
            else:
                balance_sheet.append(root + '\\' + files[0])
                profit_loss.append(root + '\\' + files[1])
        return balance_sheet, profit_loss

# %%
cashflow = file_path(r'C:\Users\cmos\Desktop\Hamid Project\Codal\tsetmc-data')
cashflow
# Out:
# ['D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آبادا\\آبادا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\آریا\\آریا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\اخابر\\اخابر-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\برکت\\برکت-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بوعلی\\بوعلی-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بپیوند\\بپیوند-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-37\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-38\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بکاب\\بکاب-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\بگیلان\\بگیلان-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\توسن\\توسن-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\توسن\\توسن-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\توسن\\توسن-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\توسن\\توسن-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\توسن\\توسن-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\توسن\\توسن-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\توسن\\توسن-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-34\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حفاری\\حفاری-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-34\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\حکشتی\\حکشتی-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-39\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-40\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خاهن\\خاهن-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\تدیزل-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\خبنیان-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\خبنیان-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\خبنیان-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\خبنیان-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبنیان\\خبنیان-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-38\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-39\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-40\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خبهمن\\خبهمن-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خصدرا\\خصدرا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-35\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-36\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خموتور\\خموتور-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\خگستر\\خگستر-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دشیمی\\دشیمی-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\دیران\\دیران-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\ذوب\\ذوب-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\رافزا\\رافزا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زاگرس\\زاگرس-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\زملارد\\زملارد-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سخواف\\سخواف-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\سیتا\\سیتا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-34\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاراک\\شاراک-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شاروم\\شاروم-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-34\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-35\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبریز\\شبریز-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبصیر\\شبصیر-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-34\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-35\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-36\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-37\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-38\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شبندر\\شبندر-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شستا\\شستا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\شسپا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شسپا\\نفت سپاهان-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شصدف\\شصدف-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شغدیر\\شغدیر-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شپنا\\شپنا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شپنا\\شپنا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شپنا\\شپنا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شپنا\\شپنا-12\\Cash Flow.xlsx',
# ...
#  'D:\\Scrape\\Files\\tsetmc-data\\شگویا\\شگویا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شگویا\\شگویا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شگویا\\شگویا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شگویا\\شگویا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شگویا\\شگویا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شگویا\\شگویا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\شگویا\\شگویا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غدام\\غدام-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غزر\\غزر-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غصینو\\غصینو-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-35\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-36\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-37\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-38\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگل\\غگل-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\غگیلا\\غگیلا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\شخلیج فارس-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فارس\\فارس-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فتوسا\\فتوسا-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فجهان\\فجهان-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فجهان\\فجهان-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فجهان\\فجهان-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فجهان\\فجهان-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فجهان\\فجهان-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فجهان\\فجهان-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فسبزوار\\فسبزوار-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فسبزوار\\فسبزوار-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فسبزوار\\فسبزوار-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فسبزوار\\فسبزوار-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فسبزوار\\فسبزوار-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-34\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-35\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-36\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-37\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-38\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-39\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فملی\\فملی-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-5\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-6\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-7\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-8\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فنفت\\فنفت-9\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-1\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-10\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-11\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-12\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-13\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-14\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-15\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-16\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-17\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-18\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-19\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-2\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-20\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-21\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-22\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-23\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-24\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-25\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-26\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-27\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-28\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-29\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-3\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-30\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-31\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-32\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-33\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-34\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-35\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-36\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-37\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-38\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-39\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-4\\Cash Flow.xlsx',
#  'D:\\Scrape\\Files\\tsetmc-data\\فولاد\\فولاد-40\\Cash Flow.xlsx',
#  ...]

# %% [markdown]
# # check_shape_befor_run

# %%
def shape(kk):
    l=pd.read_excel(kk)
    a = l.shape
    
    return a

# %%
pd.Series(balance_sheet).apply(shape).unique()
# Out:
# array([(54, 13), (34, 15), (36, 15), (47, 17), (37, 15), (44, 17),
#        (38, 17), (54, 19), (43, 13), (43, 17), (41, 17), (0, 7), (39, 17),
#        (32, 15), (13, 11)], dtype=object)

# %%
abc = pd.Series(balance_sheet).apply(shape)==(13, 11)
abc.to_excel(r'C:\Users\cmos\Desktop\abc.xlsx')

# %%
balance_sheet[3701]
# Out:
# 'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-4\\فنفت\\فنفت-40\\Balance Sheet.xlsx'

# %% [markdown]
# # type_1_function

# %%
def clean_drop_1(w):
    w.drop(w.columns[0], axis=1, inplace= True)
    w.drop(w.columns[4], axis=1, inplace= True)
    w.drop(w.columns[4], axis=1, inplace= True)
    w.dropna(axis=1 , how="all" , inplace=True)

    w.drop([1,3] , axis=0 , inplace=True)
    
    data_report = re.search(r'(\d+/\d+/\d+)', w.loc[0 , 'title']).group(1)
    w.rename(columns={0:"description" , 
#                     1:f"reported_period {str(digits.fa_to_en(w.iloc[0,1].split(' ')[-1]))}" ,
                    1:f"reported_period {str(digits.fa_to_en(data_report))}" ,
                    2:f"variable_period {str(digits.fa_to_en(w.iloc[0,2].split(' ')[-1]))}" ,
                    3:f"variable_period {str(digits.fa_to_en(w.iloc[0,3].split(' ')[-1]))}" 
                    } , inplace=True)

    return w

# %%
def new_col_1(i):
    i.insert(loc=2 , column='date_1' , value= re.sub("\/" , "-" , digits.fa_to_en(list(i.columns)[1].split(' ')[-1])))
    i.insert(loc=4 , column='date_2' , value= re.sub("\/" , "-" , digits.fa_to_en(list(i.columns)[3].split(' ')[-1])))
    i.insert(loc=6 , column='date_3' , value= re.sub("\/" , "-" , digits.fa_to_en(list(i.columns)[5].split(' ')[-1])))

    i.drop([0] , axis=0 , inplace=True)
    i.reset_index(drop=True , inplace=True)

    # i.drop(columns=['percent_change'] , inplace=True)
    
    
    
    nan_index= i[i['description'].isna()].index
    nan_index= nan_index.to_list()
    i.loc[nan_index , 'description']=['total_current_assets_befor' , 'total_current_liabilities_befor']

    
    
    i = i.replace(np.nan , '0')

    if 'حسابرسی شده' in i.iloc[0,3]:
        i.insert(loc=7 , column='audit_status_3' , value= 'audited')
    elif 'حسابرسی شده' in i.iloc[0,1]:
        i.insert(loc=7 , column='audit_status_3' , value= 'audited')
    else:
        i.insert(loc=7 , column='audit_status_3' , value= 'not_audited')
    if 'حسابرسی شده' in i.iloc[0,1]:
        i.insert(loc=5 , column='audit_status_2' , value= 'audited')
    else:
        i.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
    if 'حسابرسی شده' in i.iloc[0,11]:
        i.insert(loc=3 , column='audit_status_1' , value= 'audited')
    else:
        i.insert(loc=3 , column='audit_status_1' , value= 'not_audited')

    i.drop([0] , axis=0 , inplace=True)
    i.reset_index(drop=True , inplace=True)

    return i

# %%
def label_trans_1(y):

    y['description'].replace({'دارایی ها':'assets' ,
                                'دارایی‌‌ها':'assets' ,
                                'دارایی‌ها':'assets' ,
                                'دارایی ها':'assets' ,
                                'دریافتنی‌‌های بلندمدت': 'long_term_receivables' ,
                                'سرمایه‌گذاری‌‌های کوتاه‌مدت':'short_term_investments' ,
                                'دارایی‌‌های جاری':'current_assets' ,
                                'دارايی‌های غیرجاری':'non_current_assets' ,
                                'دارایی‌های ثابت مشهود':'tangible_fixed-assets' , 
                                'سرمایه‌گذاری در املاک':'real_estate_investments' ,
                                'دارایی‌های نامشهود':'intangible_assets' , 
                                'سرمایه‌گذاری‌های بلندمدت':'long_term_investments' , 
                                'دریافتنی‌های بلندمدت':'long_term_receivables' ,
                                'سایر دارایی‌ها':'other_assets' , 
                                'جمع دارایی‌های غیرجاری':'total_non_current_assets' , 
                                'دارایی‌های جاری':'current_assets' ,
                                'سفارشات و پیش‌پرداخت‌ها':'orders_and_prepayments' , 
                                'موجودی مواد و کالا':'inventories' , 
                                'دریافتنی‌های تجاری و سایر دریافتنی‌ها':'comercial_and_other_receivables' ,
                                'سرمایه‌گذاری‌های کوتاه‌مدت':'short_term_investments' , 
                                'موجودی نقد':'cash' , 
                                'جمع دارایی های جاری':'total_current_assets' ,
                                'جمع دارایی‌های جاری':'total_current_assets' ,
                                'دارایی‌های نگهداری شده برای فروش':'Assets_held_for_sale' , 
                                'جمع دارایی‌ها':'total_assets' , 
                                'حقوق مالکانه و بدهی‌ها':'equity_and_liabilities' ,
                                'حقوق مالکانه':'equity' , 
                                'سرمايه':'capital' , 
                                'افزایش سرمایه در جریان':'capital_increase_in_process' , 
                                'صرف سهام':'sarf_saham' ,
                                'صرف سهام خزانه':'sarf_saham_khazane' , 
                                'اندوخته قانونی':'legal_reserved' , 
                                'ساير اندوخته‌ها':'other_reserves' , 
                                'مازاد تجدیدارزيابی دارایی‌ها':'asset_revaluation_surplus' ,
                                'تفاوت تسعیر ارز عملیات خارجی':'tafavot_taseer_arz_amaliat_khareji' , 
                                'سود (زيان) انباشته':'Accumulated_(loss)_profit' , 
                                'سود انباشته':'Accumulated_(loss)_profit' ,
                                'سهام خزانه':'saham_khazane' , 
                                'جمع حقوق مالکانه':'total_equity' ,
                                'بدهی‌ها':'liabilities' , 
                                'بدهی‌های غیرجاری':'non_current_liabilities' , 
                                'پرداختنی‌های بلندمدت':'long_term_payables' , 
                                'تسهیلات مالی بلندمدت':'long_term_loans' , 
                                'ذخیره مزایای پایان خدمت کارکنان':'pention_reserved' ,
                                'جمع بدهی‌های غیرجاری':'total_non_current_liabilities' , 
                                'بدهی‌های جاری':'current_liabilities' , 
                                'پرداختنی‌های تجاری و سایر پرداختنی‌ها':'comercial_payables_and_other_payables' ,
                                'مالیات پرداختنی':'payable_taxes' , 
                                'سود سهام پرداختنی':'payable_dividends' , 
                                'تسهیلات مالی':'loans' , 
                                'ذخایر':'reserves' , 
                                'پیش‌دریافت‌ها':'pish_daryaftha' ,
                                'بدهی‌های ‌مرتبط ‌با دارایی‌های نگهداری‌‌شده برای ‌فروش':'liabilities_related_assets_held_for_sale' , 
                                'جمع بدهی‌های جاری':'total_current_liabilities' ,
                                'جمع بدهی‌ها':'total_liabilities' , 
                                'جمع حقوق مالکانه و بدهی‌ها':'total_equity_and_liabilities' , 
                                'موجودي نقد':'cash' , 
                                'مطالبات از بانک ها و ساير موسسات اعتباري':'interbank_claim' ,
                                'مطالبات از دولت':'gov_claim' , 
                                'تسهيلات اعطايي و مطالبات از اشخاص دولتي':'public_claim' , 
                                'تسهيلات اعطايي و مطالبات از اشخاص غير دولتي':'private_claim' ,
                                'سرمایه‌گذاری در سهام و ساير اوراق بهادار':'securities_investment' , 
                                'مطالبات از شرکت‌های فرعی و وابسته':'subsidiaries_claim' , 
                                'ساير حسابهاي دريافتني':'other_revceivables' ,
                                'دارایی‌هاي ثابت مشهود':'tangible_fixed-assets' , 
                                'دارایی‌هاي نا مشهود':'intangible_assets' , 
                                'سپرده قانونی':'legal_deposit' , 
                                'ساير دارایی‌ها':'other_assets' ,
                                'افزايش سرمايه در جريان':'capital_increase_in_process' , 
                                'اندوخته صرف سهام':'andokhte_sarf_saham' , 
                                'اندوخته قانوني':'legal_reserved' ,
                                'مازاد تجديد ارزيابي دارايي‌ها':'asset_revaluation_surplus' , 
                                'تفاوت تسعیر ارز':'tafavot_tseer_arz' , 
                                'بدهي به بانكها و ساير موسسات اعتباري':'interbank_liabilities' ,
                                'سپرده‌هاي مشتریان':'customer_deposits' , 
                                'سود سهام پرداختني':'payable_dividends' , 
                                'اوراق بدهی':'bond' , 
                                'ذخيره ماليات عملکرد':'operation_tax_reserve' ,
                                'ذخاير و ساير بدهی‌ها':'reserves_and_other_liabilities' , 
                                'ذخيره مزاياي پايان خدمت و تعهدات بازنشستگی کارکنان':'pention_reserved' ,
                                'جمع بدهی های قبل از حقوق صاحبان سپرده های سرمایه گذاری':'total_liabilities_befor_equity' , 
                                'حقوق صاحبان سپرده‌های سرمایه‌گذاری':'investment_deposits_owners_rights' ,
                                'جمع بدهی‌ها و حقوق مالکانه':'total_equity_and_liabilities' , 
                                'دارایی های ثابت مشهود':'tangible_fixed-assets' , 
                                'دارایی ها نامشهود':'intangible_assets' , 
                                'مطالبات از شرکت های فرعی و وابسته':'subsidiaries_claim' , 
                                'سرمایه گذاری در سهام و سایر اوراق بهادار':'securities_investment' , 
                                'سایر حساب های دریافتنی':'other_revceivables' ,
                                'سایر دارایی ها':'other_assets' , 
                                'مطالبات دولت':'gov_claim' , 
                                'تسهیلات اعطایی و مطالبات از اشخاص غیر دولتی':'private_claim' , 
                                'تسهیلات اعطایی و مطالبات از اشخاص دولتی':'public_claim' ,
                                'مطالبات از بانک ها و سایر موسسات اعتباری':'interbank_claim' , 
                                'ذخایر و سایر بدهی ها':'reserves_and_other_liabilities' , 
                                'ذخیره مالیات عملکرد':'operation_tax_reserve' ,
                                'سپرده های مشتریان':'customer_deposits' , 
                                'بدهی به بانک ها و سایر موسسات اعتباری':'interbank_liabilities' , 
                                'سرمایه‌گذاری‌‌های کوتاه مدت':'short_term_investments' ,
                                'دریافتنی‌‌های تجاری':'comercial_receivables' , 
                                'دریافتنی‌‌های غیرتجاری':'non_comercial_receivables' , 
                                'پیش پرداخت‌ها و سفارشات':'orders_and_prepayments' ,
                                'دارایی‌‌های غیرجاری':'non_current_assets' , 
                                'زمین نگهداری شده برای ساخت املاک':'land_held_for_construction' , 
                                'بدهی‌ها و حقوق صاحبان سهام':'equity_and_liabilities' ,
                                'پرداختنی‌های تجاری':'comercial_payables' , 
                                'پرداختنی‌های غیرتجاری':'non_comercial_payables' , 
                                'پیش‌دریافت‌های جاری':'current_pish_daryaftha' ,
                                'بدهی‌های مرتبط با دارایی‌های نگهداری شده برای فروش':'liabilities_related_assets_held_for_sale' , 
                                'پیش‌دریافت‌های غیرجاری':'non_current_pish_daryaftha' ,
                                'حقوق صاحبان سهام':'equity' ,
                                'سرمایه':'capital' , 
                                'افزایش (کاهش) سرمایه در جریان':'capital_increase_in_process' , 
                                'صرف (کسر) سهام':'sarf_saham' ,
                                'سایر اندوخته‌ها':'other_reserves' , 
                                'مازاد تجدید ارزیابی دارایی‌های نگهداری شده برای فروش':'revaluation_surplus_assets_held_for_sale' ,
                                'مازاد تجدید ارزیابی دارایی‌ها':'assets_revaluation_surplus' , 
                                'تفاوت تسعیر ناشی از تبدیل به واحد پول گزارشگری':'tafavot_tseer_arz' ,
                                'اندوخته تسعیر ارز دارایی‌ها و بدهی‌های شرکت‌های دولتی':'andokhte_taseer_arz-sherkat_dolati' , 
                                'سود (زیان) انباشته':'Accumulated_(loss)_profit' ,
                                'جمع حقوق صاحبان سهام':'total_equity' , 
                                'جمع بدهی‌ها و حقوق صاحبان سهام':'total_equity_and_liabilities' , 
                                'مازاد تجدید ارزیابی دارایی‌های غیرجاری نگهداری شده برای فروش':'revaluation_surplus_non_current_assets_held_for_sale' ,
                                'اندوخته تسعير ارز دارايي‌ها و بدهي‌هاي شرکت‌هاي دولتي':'andokhte_taseer_arz-sherkat_dolati' , 
                                'سرمایه گذاریهای کوتاه مدت':'short_term_investments' ,
                                'حسابها و اسناد دریافتنی تجاری':'comercial_and_other_receivables' ,
                                'طلب از شرکتهای گروه و شرکتهای وابسته':'subsidiaries_claim' , 
                                'سایر حسابها و اسناد دریافتنی':'other receivables' , 
                                'سفارشات':'orders' , 
                                'پیش پرداختها':'prepayment' , 
                                'دارایی های غیر جاری نگهداری شده برای فروش':'non_current_assets_held_for_sale' ,
                                'دارایی های غیرجاری':'non_current_assets' , 
                                'حسابها و اسناد دریافتنی بلند مدت':'long_term_receivables' , 
                                'سرمایه گذاریهای بلند مدت':'long_term_investments' ,
                                'جمع داراییهای غیر جاری':'total_non_current_assets' , 
                                'حصه جاری حسابها و اسناد دریافتنی تجاری':'short_term_receivables' , 
                                'داراییهای ثابت پس از کسر استهلاک':'fixes_assets_after_Depreciation' ,
                                'حسابها و اسناد دریافتنی تجاری(بلند مدت)':'long_term_receivables' , 
                                'پیش پرداختهای سرمایه ای':'capital_prepayments' , 
                                'مطالبات از بانک‌های مرکزی':'cbi_claims' ,
                                'مطالبات از بانک‌ها و سایر موسسات اعتباری':'interbank_claim' , 
                                'تسهیلات اعطایی و مطالبات از اشخاص دولتی به غیر از بانک‌ها':'public_claim' , 
                                'تسهیلات اعطایی و مطالبات از اشخاص غیردولتی به غیر از بانک‌ها':'private_claim' , 
                                'سرمایه‌گذاری در سهام و سایر اوراق بهادار':'securities_investment' , 
                                'مطالبات از بانک مرکزی':'cbi_claims' , 
                                'مطالبات از سایر بانکها و موسسات اعتباری':'interbank_claim' , 
                                'تسهیلات اعطایی به شرکتهای عضو گروه':'subsidiaries_claim' ,
                                'تسهیلات اعطایی به سایر اشخاص':'private_claim' , 
                                'سایر حسابهای دریافتنی':'other_receivables' , 
                                'دارایی‌های غیر جاری نگهداری شده برای فروش':'non_current_assets_held_for_sale' ,
                                'اوراق مشارکت':'corporate_bond' ,
                                'سرمایه گذاریها':'investments' , 
                                'حسابها و اسناد دریافتنی تجاری (بلند مدت)':'long_term_receivables' , 
                                'بدهی های جاری':'current_liabilities' ,
                                'حسابها و اسناد پرداختنی تجاری':'commercial_payables' , 
                                'بدهی به شرکتهای گروه و وابسته':'subsidiaries_liabilities' , 
                                'سایر حسابها و اسناد پرداختنی':'other_payables' ,
                                'پیش دریافتها':'pish_daryaftha' , 
                                'ذخیره مالیات':'tax_reserve' , 
                                'تسهیلات مالی دریافتی':'loans' , 
                                'بدهی های مرتبط با دارایی های غیر جاری نگهداری شده برای فروش':'liabilities_related_assets_held_for_sale' ,
                                'بدهی های غیر جاری':'non_current_liabilities' , 
                                'حسابها و اسناد پرداختنی بلند مدت':'long_term_payables' , 
                                'تسهیلات مالی دریافتی بلند مدت':'long_term_loans' ,
                                'جمع بدهیهای غیر جاری':'total_non_current_liabilities' , 
                                'جمع بدهی ها':'total_liabilities' , 
                                'دریافتی بابت افزایش سرمایه':'receivables_for_capital_Increase' ,
                                'سایر اندوخته ها':'other_reserves' , 
                                'ذخیره مالیات بر درآمد':'income_tax_reserves' , 
                                'حصه جاری تسهیلات مالی دریافتی':'short_term_laons' ,
                                'سود سهام پیشنهادی و پرداختنی':'payable_dividends' , 
                                'ذخیره مزایای پایان خدمت':'pention_reserved' , 
                                'جمع بدهیهای جاری و غیر جاری':'total_liabilities' ,
                                'وجوه دریافتی بابت افزایش سرمایه':'funds_received_for_capital_increase' ,
                                'اندوخته طرح و توسعه':'r&d_reserve' , 
                                'بدهی به بانک مرکزی و صندوق توسعه ملی':'ndf_cbi_liabilities' ,
                                'بدهی به بانک‌ها و سایر موسسات اعتباری':'interbank_liabilities' ,
                                'سپرده‌های دیداری و مشابه':'current_deposits' , 
                                'سپرده‌های پس‌انداز و مشابه':'savings_deposits' ,
                                'سپرده‌های سرمایه‌گذاری مدت‌دار':'investment_deposits' , 
                                'سایر سپرده‌ها':'other_deposits' , 
                                'سایر بدهی‌ها':'other_liabilities' , 
                                'بدهی به بانک مرکزی':'cbi_liabilities' ,
                                'بدهی به بانکها و موسسات اعتباری':'interbank_liabilities' , 
                                'سپرده های دیداری':'current_deposits' , 
                                'سپرده های قرض الحسنه و پس اندار و مشابه':'savings_deposits' ,
                                'سپرده های سرمایه گذاری مدت دار':'investment_deposits' , 
                                'سایر سپرده ها':'other_deposits' , 
                                'سود پرداختنی به سپرده گذاران':'depositors_dividend' ,
                                'بدهی‌های مرتبط با دارایی‌های غیر جاری نگهداری شده برای فروش':'liabilities_related_non_current_assets_held_for_sale' , 
                                'دخیره مزایای پایان خدمت کارکنان':'pention_reserves' , 
                                'مطالبات از بیمه‌گذاران و نمایندگان':'claims_on_insurers_and_agents' ,
                                'مطالبات از بیمه‌گران و بیمه‌گران اتکایی':'Claims_on_ insurers_and_reinsurers' ,
                                'سهم بیمه‌گران اتکایی از ذخایر فنی' : 'Insurers_share_of_relying_on_technical_reserves' ,
                                'سایر دریافتنی‌ها و پیش‌پرداخت‌ها':'other_recievables_and_prepayments' ,
                                'تسهیلات اعطایی به اشخاص':'private_loans' , 
                                'سرمایه‌گذاری‌ در اوراق بهادار وسپرده های بانکی':'securities_and_bank_deposits_invstments' ,
                                'سرمایه گذاری در املاک':'real_estate_investments' ,
                                'سایر سرمایه گذاری ها':'other_investments' ,
                                'دارایی های غیرجاری نگهداری شده برای فروش':'non_current_assets_held_for_sale' ,
                                'دارایی‌های نا مشهود':'intangible_assets' ,
                                'مطالبات از بيمه‌گذاران و نمايندگان':'claims_on_insurers_and_agents' ,
                                'مطالبات از بیمه گران و بيمه‌گران اتکايی':'Claims_on_ insurers_and_reinsurers' ,
                                'سهم بیمه گران اتكایی از ذخایر فنی':'Insurers_share_of_relying_on_technical_reserves' ,
                                'مطالبات بلندمدت' : 'long_term_claims' ,
                                'بدهي به بيمه‌گذاران و نمايندگان':'liabilities_on_insurers_and_agents' ,
                                'ذخاير حق بيمه' : 'insurance_premium_reserves' ,
                                'ذخيره خسارت معوق':'deferred_damages_reserves' ,
                                'ذخیره ریسک‌های منقضی نشده' : 'not_expired_reisl_reserves' ,
                                'حق بيمه سال‌های آتی' : 'future_years_insurance_premium' ,
                                'جمع دارايي‌ها':'total_assets' , 
                                'اندوخته سرمایه ای' : 'capital_reserves' ,
                                'بدهي‌ها و حقوق مالکانه':'liabilities_and_equity' ,
                                'بدهی به بیمه‌گذاران و نمایندگان':'liabilities_on_insurers_and_agents' ,
                                'بدهی به بیمه‌گران و بیمه‌گران اتکایی':'liabilities_on_insurers_and_reinsurers' ,
                                'سایر پرداختنی‌ها':'other_payables' ,
                                'بدهی بابت بیمه عمر و مدیریت سرمایه':'life_insurance_and_capital_management_liabilities' ,
                                'بدهی مرتبط با دارایی های غیرجاری نگهداری شده برای فروش':'liabilities_related_non_current_assets_held_for_sale' ,
                                'ذخیره خسارت معوق':'deferred_damages_reserves' ,
                                'ذخیره ریسکهای منقضی نشده':'not_expired_reisl_reserves' ,
                                'ذخیره حق بیمه عاید نشده':'unearned_premium_reserves' ,
                                'ذخیره ریاضی بیمه­ عمر و تشکیل سرمایه':'mathematical_reserves_of_life_insurance_and_capital_formation' ,
                                'سایر ذخایر فنی':'other_technical_reserves' ,
                                'ذخيره مزاياي پايان خدمت کارکنان':'pention_reserves' ,
                                'اندوخته سرمایه‌ای':'capital_reserves' ,
                                'تأثير تغييرات نرخ ارز':'exchange_rate_changes_effect' ,
                                'جمع بدهي‌ها و حقوق مالکانه':'total_liabilities_and_equity' ,
                                'مازاد تجديدارزيابي دارايي‌ها':'asset_revaluation_surplus' ,
                                'جمع داراییهای جاری':'total_current_assets' ,
                                'داراییهای نامشهود':'intangible_assets' ,
                                'سایر داراییها':'other_assets' ,
                                'جمع داراییها':'total_assets' ,
                                'جمع بدهیهای جاری':'total_current_liabilities' ,
                                'جمع بدهیها و حقوق صاحبان سهام':'total_equity_and_liabilities' ,
                                'داراییهای ثابت مشهود':'tangible_fixed-assets' ,
                                'مازاد تجدید ارزیابی داراییها':'asset_revaluation_surplus' ,
                                'سایر حساب‌ها و اسناد دریافتنی':'other_receivables' ,
                                'سرمایه گذاری‌های کوتاه مدت':'short_run_investment' ,
                                'طلب از شرکت‌های گروه و شرکت‌های وابسته':'subsidiaries_claim' ,
                                'حصه جاری حساب‌ها و اسناد دریافتنی تجاری' : 'short_term_receivables' ,
                                'پیش پرداخت‌ها' : 'prepayments' ,
                                'سرمایه گذاری‌های بلند مدت' : 'long_run_investments' ,
                                'دارایی‌های ثابت پس از کسر استهلاک' : 'fixes_assets_after_Depreciation' , 
                                'پیش پرداخت‌های سرمایه ای' : 'capital_prepayments' ,
                                'جمع دارایی‌های غیر جاری' : 'total_non_current_assets' ,
                                'حساب‌ها و اسناد پرداختنی تجاری':'commercial_payables' ,
                                'سایر حساب‌ها و اسناد پرداختنی' : 'other_payables' ,
                                'بدهی به شرکت‌های گروه و وابسته' : 'subsidiaries_liabilities' ,
                                'جمع بدهی‌های غیر جاری' : 'total_non_current_liabilities' , 
                                'جمع بدهی‌های جاری و غیر جاری' : 'total_liabilities' ,
                                'اندوخته تسعیر ارز داراییها و بدهیهای شرکتهای دولتی':'andokhte_taseer_arz-sherkat_dolati'} , inplace=True)



    

#     y = y.replace(np.nan , '0')
    
    return y

# %%
def col_edit_1(t):

    
    t.insert(loc= 10, column= "national_code", value= list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['shenaseh_meli'])[0])
    t.replace(t['company_name'].values, list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad'] ]['company_name_English'])[0], inplace=True)
    t.replace(t['nemad'].values, list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['en'])[0] , inplace=True)
    
#     t.insert(loc= 10, column= "national_code", value= list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['shenaseh_meli'])[0])
#     t.replace(t['nemad'].values, list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['en'])[0] , inplace=True)
#     t.replace(t['company_name'].values, list(nemad.loc[nemad['stock_name']== 'آ س پ' ]['company_name_English'])[0], inplace=True)
    

    t.replace(t['table_title'].values, "balance_sheet" , inplace=True)

    if t.loc[0,'title'].find('دوره ۶ ماهه') != -1:
        t.insert(loc=13 , column = 'reported_period' , value = "6_months_interim")
    elif t.loc[0,'title'].find('دوره ۳ ماهه') != -1:
        t.insert(loc=13 , column='reported_period' , value= "3_months_interim")
    elif t.loc[0,'title'].find('دوره ۹ ماهه') != -1:
        t.insert(loc=13 , column='reported_period' , value= "9_months_interim")
    else:
        t.insert(loc=13 , column='reported_period' , value= "12_months_interim")

    return t

# %%
def to_g(x):
    x=jdatetime.datetime(int(x.split('-')[0]) , int(x.split('-')[1]),int(x.split('-')[2])).togregorian()
    return x

# %%
def time_edit_1(r):
    r.insert(loc=14 , column="reported_date_j" , value =re.sub("\/" , "-" , digits.fa_to_en(re.search(r'(\d+/\d+/\d+)', r.loc[0 , 'title']).group(1))) )
    r.insert(loc=15 , column="reported_date_m" , value= r['reported_date_j'].apply(lambda x:to_g(x)))
    return r

# %%
def char_edit_1(ch):

    if ch.loc[0,'title'].find('حسابرسی شده') != -1:
        ch.insert(loc=16 , column='reported_audit_status' , value= "audited")
    else:
        ch.insert(loc=16 , column='reported_audit_status' , value= "not_audited")

    if ch.loc[0 , 'title'].find('اصلاحیه') != -1:
        ch.insert(loc=17 , column= 'is_corrected' , value='1')
    else:
        ch.insert(loc=17 , column= 'is_corrected' , value='0')
        
    
    ch.drop(columns=['title'] , inplace=True)

    # ch= ch.replace(np.nan , '0')
    ch[ch.columns[4]]= ch[ch.columns[4]].apply(lambda x: digits.fa_to_en(x))
    ch[ch.columns[7]]= ch[ch.columns[7]].apply(lambda x: digits.fa_to_en(x))
    ch[ch.columns[1]]= ch[ch.columns[1]].apply(lambda x: digits.fa_to_en(x))

    # ch['reported_date_j']= ch['reported_date_j'].apply(lambda x: re.sub("\/" , "-" , digits.fa_to_en(x))     #digits.fa_to_en(ch.iloc[0,5].split(' ')[-1]))  re.sub("\/" , "-" , digits.fa_to_en(data.iloc[0,14].split(' ')[-3])))
    ch['publish_time']= ch['publish_time'].apply(lambda x: digits.fa_to_en(x))
    ch['send_time']= ch['send_time'].apply(lambda x: digits.fa_to_en(x))



    return ch

# %%
def x_concat_1(table):

    table_1= table.filter(['description' , table.columns[1] , 'date_1' , 'audit_status_1' , 'national_code' , 'nemad' , 'company_name' ,
                     'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'talfighi' , 'send_time' , 'publish_time' , 'table_title'])
    table_2= table.filter(['description' , table.columns[4] , 'date_2' , 'audit_status_2' , 'national_code' , 'nemad' , 'company_name' ,
                     'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'talfighi' ,'send_time' , 'publish_time' , 'table_title'])
    table_3= table.filter(['description' , table.columns[7] , 'date_3' , 'audit_status_3' , 'national_code' , 'nemad' , 'company_name' ,
                     'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'talfighi' ,'send_time' , 'publish_time' , 'table_title'])

    table_1.rename(columns={table.columns[1]:'value' , 'date_1':'date' , 'audit_status_1':'audit_status'} , inplace=True)
    table_2.rename(columns={table.columns[4]:'value' , 'date_2':'date' , 'audit_status_2':'audit_status'} , inplace=True)
    table_3.rename(columns={table.columns[7]:'value' , 'date_3':'date' , 'audit_status_3':'audit_status'} , inplace=True)

    data_final= pd.concat([table_1 , table_2 , table_3] , ignore_index=True)

    return data_final

# %%
def total_value_1(p):
    
    p.drop(p[p.description.str.contains("شرح")].index , inplace=True)
    p.drop(p[p.description.str.contains("/")].index , inplace=True)
    p.drop(p[p.value.str.contains("/")].index , inplace=True)

    p.insert(loc=4 , column='is_total_value' , value= '0')

    index=p[p.description.str.contains('total')].index
    index=index.to_list()

    p.loc[index,'is_total_value']=1

    if p.loc[0 , 'is_corrected']=='1':
        k='_correction_'
    else:
        k='_'
          
        
        

    p.to_excel(f"C:/Users/cmos/Desktop/vemodir/{p.iloc[0,5]}_{p.iloc[0,6]}_{p.iloc[0,9]}_{p.iloc[0,11]}{k}balancesheet.xlsx" , index=False)

# %%
def final_1(path):
    total_value_1(x_concat_1(char_edit_1(time_edit_1(col_edit_1(label_trans_1(new_col_1(clean_drop_1(pd.read_excel(path)))))))))

# %%
# errorlist=[]
# def test_2(kk):
#     l = pd.read_excel(kk)
#     a = l.shape
#     if a == (54, 13):
#         try:
#             pd.Series(kk).apply(final_1)
#         except:
#             errorlist.append(kk)

# %%
# pd.Series(balance_sheet).apply(test_2)

# %%
# errorlist

# %% [markdown]
# # type_2_function

# %%
# 1st function
def drop_filter_concat(q):

    # drop all NaN rows and columns
    q.drop(q.columns[0], axis=1, inplace= True)
    q.dropna(axis=1 , how="all" , inplace=True)

    #split df to 3 tables
    q_part_1 = q.filter([q.columns[0] , q.columns[1] , q.columns[2] , q.columns[3]])
    q_part_2 = q.filter([q.columns[4] , q.columns[5] , q.columns[6] , q.columns[7]])
    q_part_3 = q.filter([q.columns[8] , q.columns[9] , q.columns[10] , q.columns[11] , q.columns[12] , q.columns[13]])

    #drop NaN rows
    q_part_1.dropna(axis=0 , how="all" , inplace=True)
    q_part_2.dropna(axis=0 , how="all" , inplace=True)

    #drop percent_change column it was useless
    q_part_1.drop(q_part_1.columns[3] , axis=1 , inplace=True)
    q_part_2.drop(q_part_2.columns[3] , axis=1 , inplace=True)

    #reset index
    q_part_1.reset_index(drop=True , inplace=True)
    q_part_2.reset_index(drop=True , inplace=True)
    q_part_3.reset_index(drop=True , inplace=True)

    #set same col names
    q_part_1.rename(columns={q_part_1.columns[0] : 'description' , 
                           q_part_1.columns[1] : 'value_1' ,
                           q_part_1.columns[2] : 'value_2'} , inplace=True)

    q_part_2.rename(columns={q_part_2.columns[0] : 'description' , 
                           q_part_2.columns[1] : 'value_1' ,
                           q_part_2.columns[2] : 'value_2'} , inplace=True)

    #concat
    q_concat = pd.concat([pd.concat([q_part_1 , q_part_2] , axis=0 , ignore_index=True) , q_part_3] , axis=1)


    return q_concat

# %%
# 2nd Finction
def date_find(d):
    date_value=[]
    try:
        if re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'value_2']).group(1) != re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'title']).group(1):
            date_value.append(re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'value_2']).group(1))
        else:
            print(False)
    except:
        print(False)

    try:
        if re.search(r'(\d+/\d+/\d+)', d.loc[1 , 'value_2']).group(1) != re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'title']).group(1):
            date_value.append(re.search(r'(\d+/\d+/\d+)', d.loc[1 , 'value_2']).group(1))
        else:
            print(False)
    except:
        print(False)

    try:
        if re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'value_1']).group(1) != re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'title']).group(1):
            date_value.append(re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'value_1']).group(1))
        else:
            print(False)
    except:
        print(False)
    
    try:
        if re.search(r'(\d+/\d+/\d+)', d.loc[1 , 'value_1']).group(1) != re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'title']).group(1):
            date_value.append(re.search(r'(\d+/\d+/\d+)', d.loc[1 , 'value_1']).group(1))
        else:
            print(False)
    except:
        print(False)




    d.insert(loc=2 , column='reported_date' , value= re.sub("\/" , "-" , digits.fa_to_en(re.search(r'(\d+/\d+/\d+)', d.loc[0 , 'title']).group(1))))
    d.insert(loc=4 , column='last_year_date' , value= re.sub("\/" , "-" ,digits.fa_to_en(date_value[0])))

    return d

# %%
# 3rd function
def final_concat(f):

    #audit column
    if f.loc[0,'title'].find('حسابرسی شده') != -1:   
        f.insert(loc=3 , column='reported_audit_status' , value= "audited")
    elif f.loc[0,'title'].find('حسابرسی نشده') != -1:
        f.insert(loc=3 , column='reported_audit_status' , value= "not_audited")
    else:
        f.insert(loc=3 , column='reported_audit_status' , value= "unknown")

    f.insert(loc=6 , column='reported_audit_status_2' , value= "unknown")



    #second concat for database form 
    f_table_1 = f.filter([f.columns[0] , f.columns[1] , f.columns[2] , f.columns[3] , f.columns[7] ,
                                             f.columns[8] , f.columns[9] , f.columns[10] , f.columns[11] , f.columns[12]])
    f_table_2 = f.filter([f.columns[0] , f.columns[4] , f.columns[5] , f.columns[6] , f.columns[7] ,
                                              f.columns[8] , f.columns[9] , f.columns[10] , f.columns[11] , f.columns[12]])

    f_table_1.rename(columns={f_table_1.columns[1]:'value' , f_table_1.columns[2]:'date' , f_table_1.columns[3]:'audit_status'} , inplace=True)
    f_table_2.rename(columns={f_table_2.columns[1]:'value' , f_table_2.columns[2]:'date' , f_table_2.columns[3]:'audit_status'} , inplace=True)

    f_final_concat = pd.concat([f_table_1 , f_table_2])
    
    f_final_concat.replace(np.nan , '0' , inplace=True)

    return f_final_concat

# %%
# 4th function
def char_correction(ch):
#     ch.replace(np.nan , '0' , inplace=True)

    ch.insert(loc= 4, column= "national_code", value= str(list(nemad.loc[nemad['stock_name']== list(ch.loc[0 , 'nemad'])[0]]['shenaseh_meli'])[0]))
    ch['company_name'] = ch['company_name'].replace(ch['company_name'].values, list(nemad.loc[nemad['stock_name']== list(ch.loc[0 , 'nemad'])[0]]['company_name_English'])[0])
    ch['nemad'] = ch['nemad'].replace(ch['nemad'].values, list(nemad.loc[nemad['stock_name']== list(ch.loc[0 , 'nemad'])[0]]['en'])[0])
    
    
       
    
#     ch.insert(loc= 4, column= "national_code", value= str(list(nemad.loc[nemad['stock_name']== list(ch.loc[0 , 'nemad'])[0]]['shenaseh_meli'])[0]))
#     ch['nemad'] = ch['nemad'].replace(ch['nemad'].values, list(nemad.loc[nemad['stock_name']== ch.loc[0 , 'nemad']]['en'][0]))
#     ch['company_name']=ch['company_name'].replace(ch['company_name'].values, list(nemad.loc[nemad['stock_name']== ch.loc[0 , 'nemad']]['company_name_English'])[0])
#     ch['company_name']= ch['company_name'].replace(ch['company_name'].values, list(nemad.loc[nemad['stock_name']== list(ch.loc[0 , 'nemad'])[0]]['company_name_English'])[0])
#     ch['nemad'] = ch['nemad'].replace(ch['nemad'].values, list(nemad.loc[nemad['stock_name']== 'آ س پ' ]['en'])[0])
#     ch['company_name']=ch['company_name'].replace(ch['company_name'].values, list(nemad.loc[nemad['stock_name']== 'آ س پ' ]['company_name_English'])[0])
    
    
    # adding national code col

    # char correction
    ch['table_title']=ch['table_title'].replace(ch['table_title'].values, "balance_sheet" )
    ch['send_time']= ch['send_time'].replace(list(ch['send_time']) , ch.iloc[0 , 8])
    ch['publish_time']= ch['publish_time'].replace(list(ch['publish_time']) , ch.iloc[0 , 8])

    #persian number to english number
    ch[ch.columns[1]]= ch[ch.columns[1]].apply(lambda x: digits.fa_to_en(x))
    ch['publish_time']= ch['publish_time'].apply(lambda x: digits.fa_to_en(x))
    ch['send_time']= ch['send_time'].apply(lambda x: digits.fa_to_en(x))

    return ch

# %%
# 6th function
def title_split(j):
  
    # get report period from title
    if j.iloc[0,7].find('دوره ۶ ماهه') != -1:
        j.insert(loc=7 , column = 'reported_period' , value = "6_months_interim")
    elif j.iloc[0,7].find('دوره ۳ ماهه') != -1:
        j.insert(loc=7 , column='reported_period' , value= "3_months_interim")
    elif j.iloc[0,7].find('دوره ۹ ماهه') != -1:
        j.insert(loc=7 , column='reported_period' , value= "9_months_interim")
    else:
        j.insert(loc=7 , column='reported_period' , value= "12_months_interim")


    # get report date from title
    j.insert(loc=8 , column="reported_date_j" , value =re.sub("\/" , "-" , digits.fa_to_en(re.search(r'(\d+/\d+/\d+)', j.iloc[0 , 8]).group(1))) )
    j.insert(loc=9 , column="reported_date_m" , value= j['reported_date_j'].apply(lambda x:to_g(x)))


    # get audit status from title
    if j.iloc[0 , 10].find('حسابرسی شده') != -1:
        j.insert(loc=10 , column='reported_audit_status' , value= "audited")
    elif j.iloc[0, 10].find('حسابرسی نشده') != -1:
        j.insert(loc=10 , column='reported_audit_status' , value= "not_audited")
    else:
        j.insert(loc=10 , column='reported_audit_status' , value= "unknown")

    if j.iloc[0 , 11].find('اصلاحیه') != -1:
        j.insert(loc=11 , column= 'is_corrected' , value='1')
    else:
        j.insert(loc=11 , column= 'is_corrected' , value='0')



    j.drop(columns=['title'] , inplace=True)

    return j

# %%
# 8th function
def final_drop(ff):

    ff.drop(ff[ff.description.str.contains("شرح")].index , inplace=True)
#     ff.drop(ff[ff.description.str.contains("۱۴" or  "۱۳" or "14" or "13")].index , inplace=True)
#     ff.drop(ff[ff.value.str.contains("۱۴" or  "۱۳" or "14" or "13")].index , inplace=True)

    ff.drop(ff[ff.description.str.contains("/")].index , inplace=True)
    ff.drop(ff[ff.value.str.contains("/")].index , inplace=True)
    
    

    ff.reset_index(drop=True , inplace=True)

    return ff

# %%
# 9th function
def total_value(pp):

    pp.insert(loc=4 , column='is_total_value' , value= '0')

    index=pp[pp.description.str.contains('total')].index
    index=index.to_list()

    pp.loc[index,'is_total_value']=1

    if pp.loc[0 , 'is_corrected']=='1':
        k='_correction_'
    else:
        k='_'
        
        
    pp.to_excel(f"C:/Users/cmos/Desktop/vemodir/{pp.iloc[0,5]}_{pp.iloc[0,6]}_{pp.iloc[0,9]}_{pp.iloc[0,11]}{k}balancesheet.xlsx" , index=False)

# %%
def export(path):
    total_value(final_drop(label_trans_1(title_split(char_correction(final_concat(date_find(drop_filter_concat(pd.read_excel(path)))))))))

# %% [markdown]
# # get_export_by_shape

# %%
errorlist_1 = []
errorlist_2 = []
errorlist_3 = []
errorlist_4 = []
errorlist_5 = []
errorlist_6 = []
errorlist_7 = []
errorlist_7 = []
errorlist_8 = []
errorlist_9 = []
errorlist_10 = []
errorlist_11 = []
errorlist_12 = []
errorlist_13 = []




def test_1(kk):
    l = pd.read_excel(kk)
    a = l.shape
    
    if a == (38, 17):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_1.append(kk)

    if a == (44, 17):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_2.append(kk)
            
    if a == (36, 15):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_3.append(kk)
            
    if a == (37, 15):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_4.append(kk)
            
    if a == (34, 15):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_5.append(kk)
            
    if a == (47, 17):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_6.append(kk)
                        
    if a == (43, 17):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_7.append(kk)
            
    if a == (41, 17):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_8.append(kk)
            
                            
    if a == (39, 17):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_9.append(kk)
            
                
    if a == (36, 15):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_10.append(kk)
                   
    if a == (32, 15):
        try:
            pd.Series(kk).apply(export)
        except:
            errorlist_11.append(kk) 
                   
    if a == (43, 13):
        try:
            pd.Series(kk).apply(final_1)
        except:
            errorlist_12.append(kk)
                
    if a == (54, 13):
        try:
            pd.Series(kk).apply(final_1)
        except:
            errorlist_13.append(kk)

# %%
pd.Series(balance_sheet).apply(test_1)
# Out:
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# False
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# dtype: object

# %%
errorlist_1
# Out:
# []

# %%
errorlist_2
# Out:
# []

# %%
errorlist_3
# Out:
# []

# %%
errorlist_4
# Out:
# []

# %%
errorlist_5
# Out:
# []

# %%
errorlist_6
# Out:
# []

# %%
errorlist_7
# Out:
# []

# %%
errorlist_8
# Out:
# []

# %%
errorlist_9
# Out:
# []

# %%
errorlist_10
# Out:
# []

# %%
errorlist_11
# Out:
# []

# %%
errorlist_12
# Out:
# []

# %%
errorlist_13
# Out:
# []

# %%
# error_list_all = []
# try:
#     pd.Series(balance_sheet).apply(test_1)
# except:
#     error_list_all.append(balance_sheet)

# %%
# error_list_all
