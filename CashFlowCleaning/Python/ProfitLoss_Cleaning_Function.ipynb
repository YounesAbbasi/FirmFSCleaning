# %%
import pandas as pd
import numpy as np
import re
from persiantools import characters, digits
import jdatetime
import os

# %%
nemad = pd.read_excel(r'C:\Users\cmos\Desktop\nemad_info.xlsx')

# %%
def file_path(path):
    if __name__ == "__main__":
        balance_sheet = []
        profit_loss = []
        for (root, dirs, files) in os.walk(path , topdown = True):
            if len(files) == 0:
                continue
            else:
                balance_sheet.append(root + '\\' + files[0])
                profit_loss.append(root + '\\' + files[1])
        return balance_sheet, profit_loss

# %%
balance_sheet , profit_loss = file_path(r'C:\Users\cmos\Desktop\Hamid Project\Codal\tsetmc-data\part-2\وسدید')
profit_loss
# Out:
# ['C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-1\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-10\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-11\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-12\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-13\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-14\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-15\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-16\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-17\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-18\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-19\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-2\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-20\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-21\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-22\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-23\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-24\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-25\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-26\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-27\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-28\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-29\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-3\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-30\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-31\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-32\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-34\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-35\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-36\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-37\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-38\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-39\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-4\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-40\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-41\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-42\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-43\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-44\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-45\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-47\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-48\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-49\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-5\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-50\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-52\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-53\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-54\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-55\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-56\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-58\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-59\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-6\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-60\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-61\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-62\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-64\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-65\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-66\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-67\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-7\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-76\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-78\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-79\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-8\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-80\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-81\\Income Statement.xlsx',
#  'C:\\Users\\cmos\\Desktop\\Hamid Project\\Codal\\tsetmc-data\\part-2\\وسدید\\وسدید-9\\Income Statement.xlsx']

# %%
def shape(kk):
    l=pd.read_excel(kk)
    a = l.shape
    
    return a

pd.Series(profit_loss).apply(shape).unique()
# Out:
# array([(56, 13), (64, 12), (64, 13), (45, 13), (45, 12), (19, 13)],
#       dtype=object)

# %%
b = pd.Series(profit_loss).apply(shape) == (19, 13)
b.to_excel(r'C:\Users\cmos\Desktop\tttt.xlsx')

# %%
len(pd.Series(profit_loss))
# Out:
# 57

# %%
pd.read_excel(profit_loss[65])
# Out:
#     Unnamed: 0    0                                                 1  \
# 0            0  شرح  واقعی\nدوره منتهی به\n۱۳۸۹/۱۲/۲۹\n(حسابرسی نشده)
# 1            1  NaN                                               NaN
# 2            2  NaN                                               NaN
# 3            3  NaN                                               NaN
# 4            4  NaN                                               NaN
# 5            5  NaN                                               NaN
# 6            6  NaN                                               NaN
# 7            7  NaN                                     دوره منتهی به
# 8            8  NaN                                               NaN
# 9            9  NaN                                               NaN
# 10          10  NaN                                               NaN
# 11          11  NaN                                               NaN
# 12          12  NaN                                               NaN
# 13          13  NaN                                               NaN
# 14          14  NaN                                               NaN
# 15          15  NaN                                               NaN
# 16          16  NaN                                               NaN
# 17          17  NaN                                               NaN
# 18          18  NaN                                               NaN
#
#                                                    2              3  \
# 0   واقعی\nدوره منتهی به\n۱۳۸۸/۱۲/۲۹\n(حسابرسی نشده)  درصد\nتغییرات
# 1                                                NaN            NaN
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4                                                NaN            NaN
# 5                                                NaN            NaN
# 6                                                NaN            NaN
# 7                                         ۱۳۸۹/۱۲/۲۹     ۱۳۸۸/۱۲/۲۹
# 8                                                NaN            NaN
# 9                                                NaN            NaN
# 10                                               NaN            NaN
# 11                                               NaN            NaN
# 12                                               NaN            NaN
# 13                                               NaN            NaN
# 14                                               NaN            NaN
# 15                                               NaN            NaN
# 16                                               NaN            NaN
# 17                                               NaN            NaN
# 18                                               NaN            NaN
#
#                                                     4           5 nemad  \
# 0   واقعی\nسال مالی منتهی به\n۱۳۸۹/۰۹/۳۰\n(حسابرسی...         NaN  سمگا
# 1                                                 NaN         NaN  سمگا
# 2                                                 NaN         NaN  سمگا
# 3                                                 NaN         NaN  سمگا
# 4                                                 NaN         NaN  سمگا
# 5                                                 NaN         NaN  سمگا
# 6                                                 NaN         NaN  سمگا
# 7                                                 NaN  ۱۳۸۹/۰۹/۳۰  سمگا
# 8                                                 NaN         NaN  سمگا
# 9                                                 NaN         NaN  سمگا
# 10                                                NaN         NaN  سمگا
# 11                                                NaN         NaN  سمگا
# 12                                                NaN         NaN  سمگا
# 13                                                NaN         NaN  سمگا
# 14                                                NaN         NaN  سمگا
# 15                                                NaN         NaN  سمگا
# 16                                                NaN         NaN  سمگا
# 17                                                NaN         NaN  سمگا
# 18                                                NaN         NaN  سمگا
#
#                                       company_name  \
# 0   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 1   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 2   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 3   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 4   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 5   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 6   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 7   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 8   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 9   گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 10  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 11  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 12  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 13  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 14  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 15  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 16  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 17  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
# 18  گروه سرمایه گذاری میراث فرهنگی و گردشگری ایران
#
#                                                 title            send_time  \
# 0   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 1   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 2   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 3   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 4   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 5   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 6   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 7   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 8   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 9   اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 10  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 11  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 12  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 13  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 14  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 15  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 16  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 17  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
# 18  اطلاعات و صورتهای مالی میاندوره ای دوره ۳ ماهه...  ۱۳۹۰/۰۲/۱۱ ۱۷:۳۶:۰۱
#
#            publish_time       table_title
# 0   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 1   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 2   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 3   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 4   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 5   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 6   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 7   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 8   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 9   ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 10  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 11  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 12  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 13  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 14  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 15  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 16  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 17  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement
# 18  ۱۳۹۰/۰۲/۱۲ ۰۹:۴۲:۵۹  Income Statement

# %%
def clean_drop_2(w):
    
    if len(w.columns) == 13 :

        w.iloc[0 , 6] = w.iloc[0 , 5]
        w.iloc[0 , 5] = w.iloc[0 , 4]
        w.iloc[0 , 4] = w.iloc[0 , 3]
        w.iloc[0 , 3] = w.iloc[0 , 2]
        w.iloc[0 , 2] = w.iloc[0 , 1]

        w.drop(w.columns[0], axis=1, inplace= True)
        w.drop(w[w.columns[1:7]].isna().sum() >30 , axis=1, inplace= True)

    #     w.drop(w.columns[0], axis=1, inplace= True)
        w.drop(w.columns[3], axis=1, inplace= True)
    #     w.dropna(axis=1 , how="all" , inplace=True)

#         w[w.columns[0]].replace(np.nan , 'ec' , inplace=True)
#         w.drop(w[w[w.columns[0]]=='ec'].index.tolist() , axis=0 , inplace=True)

        data_report_1 = re.search(r'(\d+/\d+/\d+)', w.loc[0 , 'title']).group(1)
        data_report_2 = re.search(r'(\d+/\d+/\d+)', w.loc[0 , w.columns[2]]).group(1)
        data_report_3 = re.search(r'(\d+/\d+/\d+)', w.loc[0 , w.columns[3]]).group(1)

        w.rename(columns={w.columns[0]:"description" , 
                          w.columns[1]:f"reported_period {str(digits.fa_to_en(data_report_1))}" ,
                          w.columns[2]:f"variable_period {str(digits.fa_to_en(data_report_2))}" ,
                          w.columns[3]:f"variable_period {str(digits.fa_to_en(data_report_3))}" } , inplace=True)
    
    
    elif len(w.columns) == 12 :
        
        w.iloc[0 , 5] = w.iloc[0 , 4]
        w.iloc[0 , 4] = w.iloc[0 , 3]
        w.iloc[0 , 3] = w.iloc[0 , 2]
        w.iloc[0 , 2] = w.iloc[0 , 1]

        w.drop(w.columns[0], axis=1, inplace= True)
        w.drop(w[w.columns[1:7]].isna().sum() >30 , axis=1, inplace= True)

    #     w.drop(w.columns[0], axis=1, inplace= True)
        w.drop(w.columns[3], axis=1, inplace= True)
    #     w.dropna(axis=1 , how="all" , inplace=True)

#         w[w.columns[0]].replace(np.nan , 'ec' , inplace=True)
#         w.drop(w[w[w.columns[0]]=='ec'].index.tolist() , axis=0 , inplace=True)

        data_report_1 = re.search(r'(\d+/\d+/\d+)', w.loc[0 , 'title']).group(1)
        data_report_2 = re.search(r'(\d+/\d+/\d+)', w.loc[0 , w.columns[2]]).group(1)

        w.rename(columns={w.columns[0]:"description" , 
                          w.columns[1]:f"reported_period {str(digits.fa_to_en(data_report_1))}" ,
                          w.columns[2]:f"variable_period {str(digits.fa_to_en(data_report_2))}" } , inplace=True)
        
        
        
    if len(w.columns) == 9 :

        w.insert(loc=2 , column='date_1' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[1].split(' ')[-1])))
        w.insert(loc=4 , column='date_2' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[3].split(' ')[-1])))

#         w.drop([0] , axis=0 , inplace=True)
        w.reset_index(drop=True , inplace=True)

        w = w.replace(np.nan , '0')

            
        if 'حسابرسی شده' in w.iloc[0,3]:
            w.insert(loc=5 , column='audit_status_2' , value= 'audited')
        elif 'حسابرسی نشده' in w.iloc[0,3]:
            w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
        else:
            w.insert(loc=5 , column='audit_status_2' , value= 'unknown')
    

        if 'حسابرسی شده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'audited')
        elif 'حسابرسی نشده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'not_audited')
        else:
            w.insert(loc=3 , column='audit_status_1' , value= 'unknown')

            
        w.drop([0] , axis=0 , inplace=True)
        
        w.drop(w[w[w.columns[0]] == "0"].index.tolist() , axis=0 , inplace=True)
        w.drop(w[w.description.str.contains("حسابرس")].index , inplace=True)
        w.reset_index(drop=True , inplace=True)
        w.drop([0] , axis=0 , inplace=True)
        w.reset_index(drop=True , inplace=True)

        
            

    elif len(w.columns) == 10 :

        w.insert(loc=2 , column='date_1' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[1].split(' ')[-1])))
        w.insert(loc=4 , column='date_2' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[3].split(' ')[-1])))
        w.insert(loc=6 , column='date_3' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[5].split(' ')[-1])))

#         w.drop([0] , axis=0 , inplace=True)
        w.reset_index(drop=True , inplace=True)

        w = w.replace(np.nan , '0')

                
        if 'حسابرسی شده' in w.iloc[0,5]:
            w.insert(loc=7 , column='audit_status_3' , value= 'audited')
        elif 'حسابرسی نشده' in w.iloc[0,5]:
            w.insert(loc=7 , column='audit_status_3' , value= 'not_audited')  
        else:
            w.insert(loc=7 , column='audit_status_3' , value= 'unknown')

        if 'حسابرسی شده' in w.iloc[0,3]:
            w.insert(loc=5 , column='audit_status_2' , value= 'audited')
        elif 'حسابرسی نشده' in w.iloc[0,3]:
            w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
        else:
            w.insert(loc=5 , column='audit_status_2' , value= 'unknown')


        if 'حسابرسی شده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'audited')
        elif 'حسابرسی نشده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'not_audited')
        else:
            w.insert(loc=3 , column='audit_status_1' , value= 'unknown')

        w.drop([0] , axis=0 , inplace=True)
        
        w.drop(w[w[w.columns[0]] == "0"].index.tolist() , axis=0 , inplace=True)
        w.drop(w[w.description.str.contains("حسابرس")].index , inplace=True)
        w.reset_index(drop=True , inplace=True)
        w.drop([0] , axis=0 , inplace=True)
        w.reset_index(drop=True , inplace=True)

    

    return w

# %%
def clean_drop_1(w):

    value_droped_1 = []
    w.drop(w.columns[0], axis=1, inplace= True)
    w.dropna(axis=1 , how="all" , inplace=True)
    
    
    f = w.iloc[: , 1:7].isna().sum() > 30

                
    if f.any() == True :
        try:
            if w.iloc[: , 2].isna().sum() > 30 :      
                try :
                    if list(w[w[w.columns[2]] == 'حسابرسی شده'][w.columns[2]] == 'حسابرسی شده' )[0]== True :
                        value_droped_1.append('حسابرسی شده')
                        w.drop(w.columns[2], axis=1, inplace= True)
                except :
                    print(False)

                try:
                    if list(w[w[w.columns[2]] == 'حسابرسی نشده'][w.columns[2]] == 'حسابرسی نشده' )[0]== True :
                        value_droped_1.append('حسابرسی نشده')
                        w.drop(w.columns[2], axis=1, inplace= True)
                except :
                    print(None)
            else :
                print(False)
        except:
            print(False)
             
        try:        
            if w.iloc[: , 3].isna().sum() > 30 :  
                try:

                    if list(w[w[w.columns[3]] == 'حسابرسی شده'][w.columns[2]] == 'حسابرسی شده' )[0] == True :
                        value_droped_1.append('حسابرسی شده')
                        w.drop(w.columns[3], axis=1, inplace= True)
                except :
                    print(False)

                try:
                    if list(w[w[w.columns[3]] == 'حسابرسی نشده'][w.columns[2]] == 'حسابرسی نشده' )[0]== True :
                        value_droped_1.append('حسابرسی نشده')
                        w.drop(w.columns[3], axis=1, inplace= True)
                except :
                    print(False)
            else:
                print(False)
        except:
            print(False)

                
        
    if w.iloc[0 , 5].find('درصد') != -1 :
        w.drop(w.columns[5], axis=1, inplace= True)
    elif w.iloc[0 , 4].find('درصد') != -1 :
        w.drop(w.columns[4], axis=1, inplace= True)
    elif w.iloc[0 , 3].find('درصد') != -1 :
        w.drop(w.columns[3], axis=1, inplace= True)
    else :
        print ('not_found')

#     w.drop(w[w.columns[1:7]].isna().sum() >30 , axis=1, inplace= True)
    
    if len(w.columns) == 9 :
        data_report_1 = re.search(r'(\d+/\d+/\d+)', w.loc[0 , 'title']).group(1)
        data_report_2 = re.search(r'(\d+/\d+/\d+)', w.iloc[0 , 2]).group(1)
        w.rename(columns={w.columns[0]:"description" , 
                          w.columns[1]:f"reported_period {str(digits.fa_to_en(data_report_1))}" ,
                          w.columns[2]:f"variable_period {str(digits.fa_to_en(data_report_2))}" ,
                          } , inplace=True)
        
    elif len(w.columns) == 10 :
        data_report_1 = re.search(r'(\d+/\d+/\d+)', w.loc[0 , 'title']).group(1)
        data_report_2 = re.search(r'(\d+/\d+/\d+)', w.iloc[0 , 2]).group(1)
        data_report_3 = re.search(r'(\d+/\d+/\d+)', w.iloc[0 , 3]).group(1)
        
        
        w.rename(columns={w.columns[0]:"description" , 
                          w.columns[1]:f"reported_period {str(digits.fa_to_en(data_report_1))}" ,
                          w.columns[2]:f"variable_period {str(digits.fa_to_en(data_report_2))}" ,
                          w.columns[3]:f"variable_period {str(digits.fa_to_en(data_report_3))}" 
                          } , inplace=True)

        
        
         
        
        
        
    if len(w.columns) == 9 :

        w.insert(loc=2 , column='date_1' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[1].split(' ')[-1])))
        w.insert(loc=4 , column='date_2' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[3].split(' ')[-1])))

#         w.drop([0] , axis=0 , inplace=True)
        w.reset_index(drop=True , inplace=True)

        w = w.replace(np.nan , '0')

        if len(value_droped_1) == 1 :
            
            if 'حسابرسی شده' in value_droped_1 :
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            if 'حسابرسی نشده' in value_droped_1 :
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
                
        elif len(value_droped_1) == 0 :
            
            if 'حسابرسی شده' in w.iloc[1,2]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[1,2]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[2,2]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[2,2]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[3,2]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[3,2]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[1,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[1,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')    
            elif 'حسابرسی شده' in w.iloc[2,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[2,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')    
            elif 'حسابرسی شده' in w.iloc[3,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[3,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')   
            elif 'حسابرس' in w.iloc[0 , 1]:
                if 'حسابرسی شده' in w.iloc[1,0]:
                    w.insert(loc=5 , column='audit_status_2' , value= 'audited')
                elif 'حسابرسی نشده' in w.iloc[1,0]:
                    w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
                elif 'حسابرسی شده' in w.iloc[2,0]:
                    w.insert(loc=5 , column='audit_status_2' , value= 'audited')
                elif 'حسابرسی نشده' in w.iloc[2,0]:
                    w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
                elif 'حسابرسی شده' in w.iloc[3,0]:
                    w.insert(loc=5 , column='audit_status_2' , value= 'audited')
                elif 'حسابرسی نشده' in w.iloc[3,0]:
                    w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            else:
                w.insert(loc=5 , column='audit_status_2' , value= 'unknown')
    

        if 'حسابرسی شده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'audited')
        elif 'حسابرسی نشده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'not_audited')
        else:
            w.insert(loc=3 , column='audit_status_1' , value= 'unknown')

            
        w.drop([0] , axis=0 , inplace=True)
#         w.drop([1] , axis=0 , inplace=True)
        w.drop(w[w[w.columns[0]] == "0"].index.tolist() , axis=0 , inplace=True)
        w.drop(w[w.description.str.contains("حسابرس")].index , inplace=True)
        w.reset_index(drop=True , inplace=True)

        
        
        

    elif len(w.columns) == 10 :

        w.insert(loc=2 , column='date_1' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[1].split(' ')[-1])))
        w.insert(loc=4 , column='date_2' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[3].split(' ')[-1])))
        w.insert(loc=6 , column='date_3' , value= re.sub("\/" , "-" , digits.fa_to_en(list(w.columns)[5].split(' ')[-1])))

#         w.drop([0] , axis=0 , inplace=True)
        w.reset_index(drop=True , inplace=True)

        w = w.replace(np.nan , '0')

        if len(value_droped_1) == 1 :
            if 'حسابرسی شده' in value_droped_1 :
                w.insert(loc=5 , column='audit_status_3' , value= 'audited')
            if 'حسابرسی نشده' in value_droped_1 :
                w.insert(loc=5 , column='audit_status_3' , value= 'not_audited')
                
        elif len(value_droped_1) == 0 :
            if 'حسابرسی شده' in w.iloc[1,3]:
                w.insert(loc=7 , column='audit_status_3' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[1,3]:
                w.insert(loc=7 , column='audit_status_3' , value= 'not_audited') 
            elif 'حسابرسی شده' in w.iloc[2,3]:
                w.insert(loc=7 , column='audit_status_3' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[2,3]:
                w.insert(loc=7 , column='audit_status_3' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[3,3]:
                w.insert(loc=7 , column='audit_status_3' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[3,3]:
                w.insert(loc=7 , column='audit_status_3' , value= 'not_audited') 
            elif 'حسابرس' in w.iloc[0 , 1]:
                if 'حسابرسی شده' in w.iloc[1,1]:
                    w.insert(loc=7 , column='audit_status_3' , value= 'audited')
                elif 'حسابرسی نشده' in w.iloc[1,1]:
                    w.insert(loc=7 , column='audit_status_3' , value= 'not_audited') 
                elif 'حسابرسی شده' in w.iloc[2,1]:
                    w.insert(loc=7 , column='audit_status_3' , value= 'audited')
                elif 'حسابرسی نشده' in w.iloc[2,1]:
                    w.insert(loc=7 , column='audit_status_3' , value= 'not_audited') 
                elif 'حسابرسی شده' in w.iloc[3,1]:
                    w.insert(loc=7 , column='audit_status_3' , value= 'audited')
                elif 'حسابرسی نشده' in w.iloc[3,1]:
                    w.insert(loc=7 , column='audit_status_3' , value= 'not_audited') 
            else:
                w.insert(loc=7 , column='audit_status_3' , value= 'unknown')

        if 'حسابرس' in w.iloc[0 , 1]:
            if 'حسابرسی شده' in w.iloc[1,0]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[1,0]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[2,0]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[2,0]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[3,0]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[3,0]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            else:
                w.insert(loc=5 , column='audit_status_2' , value= 'unknown')
        else:
            if 'حسابرسی شده' in w.iloc[1,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[1,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[2,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[2,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            elif 'حسابرسی شده' in w.iloc[3,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'audited')
            elif 'حسابرسی نشده' in w.iloc[3,1]:
                w.insert(loc=5 , column='audit_status_2' , value= 'not_audited')
            else:
                w.insert(loc=5 , column='audit_status_2' , value= 'unknown')


        if 'حسابرسی شده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'audited')
        elif 'حسابرسی نشده' in w.loc[0, 'title']:
            w.insert(loc=3 , column='audit_status_1' , value= 'not_audited')
        else:
            w.insert(loc=3 , column='audit_status_1' , value= 'unknown')

        w.drop([0] , axis=0 , inplace=True)
        w.drop(w[w[w.columns[0]] == "0"].index.tolist() , axis=0 , inplace=True)
        w.drop(w[w.description.str.contains("حسابرس")].index , inplace=True)
        w.reset_index(drop=True , inplace=True)


    return w

# %%
def label_trans_1(y):

    y['description']=y['description'].replace({'سود (زیان) خالص' : 'net_profit' ,
                              'درآمدهای عملیاتی' : 'operating_Income' , 
                              'درآمد سود سهام' : 'dividends_income' ,
                              'درآمد سود تضمین شده' : 'guaranteed_profit_income' ,
                              'سود (زیان) فروش سرمایه گذاری ها' : 'profti_sales _of_investments' ,
                              'سود (زیان) تغییر ارزش سرمایه گذاری در اوراق بهادار' : 'profit_change_in_securities_investments_value' ,
                              'سایر درآمدهای عملیاتی' : 'other_operating_income' ,
                              'جمع درآمدهای عملیاتی' : 'total_operating_income' ,
                              'هزینه های عملیاتی' : 'operating_expenses' ,
                              'هزینه‌های فروش، اداری و عمومی' : 'selling_general_administrative_expenses' ,
                              'سایر هزینه‌های عملیاتی' : 'other_operating_expenses' ,
                              'جمع هزینه های عملیاتی' : 'total_operating_expenses' ,
                              'سود (زیان) عملیاتی' : 'operating_profit' ,
                              'هزینه‌های مالی' : 'financial_cost' , 
                              'سایر درآمدها و هزینه‌های غیرعملیاتی' : 'other_non_operating_income_and_expenses' ,
                              'سود (زیان) عملیات در حال تداوم قبل از مالیات' : 'profit_operations_in_progress_before_tax' ,
                              'مالیات بر درآمد' : 'income_tax' ,
                              'سود (زیان) خالص عملیات در حال تداوم' : 'profit_operations_in_progress' ,
                              'سود (زیان) عملیات متوقف ‌شده پس از اثر مالیاتی' : 'profit_stopped_operations_after_tax_effect' ,
                              'سود (زیان) پایه هر سهم' : 'profit_per_share' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات در حال تداوم- عملیاتی' : 'profit_per_share_due_to_(operating)_operations_in_progress' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات در حال تداوم- غیرعملیاتی' : 'profit_per_share_due_to_(non_operating)_operations_in_progress' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات متوقف ‌شده' : 'profit_per_share_due_to_stopped_operations' ,
                              'سود (زیان) تقلیل یافته هر سهم' : 'reduced_profit_per_share' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات در حال تداوم- عملیاتی' : 'reduced_profit_per_share_due_to_(operating)_operations_in_progress' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات در حال تداوم- غیرعملیاتی' : 'reduced_profit_per_share_due_to_(non_operating)_operations_in_progress' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات متوقف‌ شده' : 'reduced_profit_per_share_due_to_stopped_operations' ,
                              'گردش حساب سود (زیان) انباشته' : 'accumulated_profit_account_turnover' , 
                              'سود (زیان) انباشته ابتدای دوره' : 'accumulated_profit_beginning_of_period' ,
                              'تعدیلات سنواتی' : 'annual_adjustments' ,
                              'سود (زیان) انباشته ابتدای دوره تعدیل‌شده' : 'accumulated_profit_beginning_of_adjusted_period' ,
                              'سود سهام‌ مصوب' : 'approved_dividend' ,
                              'تغییرات سرمایه از محل سود (زیان) انباشته' : 'capital_changes_from_accumulated_profit' ,
                              'سود (زیان) انباشته ابتدای دوره تخصیص نیافته' : 'accumulated_profit_beginning_of_unallocated_period' ,
                              'انتقال از سایر اقلام حقوق صاحبان سهام' : 'transfer_of_other_equity_items' ,
                              'سود قابل تخصیص' : 'distributable_profit' ,
                              'انتقال به اندوخته‌ قانوني‌' : 'transfer_to_legal_reserve' ,
                              'انتقال به سایر اندوخته‌ها' : 'transfer_to_other_reserve' ,
                              'سود (زیان) انباشته‌ پايان‌ دوره' : 'accumulated_profit_end_of_period' ,
                              'سود (زیان) خالص هر سهم- ریال' : 'net_profit_per_share_(rial)' ,
                              'سرمایه' : 'capital' ,
                              'بهای تمام ‌شده درآمدهای عملیاتی' : 'expenses_of_operating_income' ,
                              'سود (زیان) ناخالص' : 'gross_profit' ,
                              'سایر درآمدها و هزینه‌های غیرعملیاتی- درآمد سرمایه‌گذاری‌ها' : 'other_non_operating_income_expenses_(investment_income)' ,
                              'سایر درآمدها و هزینه‌های غیرعملیاتی- اقلام متفرقه' : 'other_non_operating_income_expenses_(other_item)' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات متوقف‌ شده' : 'profit_per_share_due_to_stopped_operations' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات متوقف ‌شده' : 'reduced_profit_per_share_due_to_stopped_operations' ,
                              'سود (زیان) انباشته ابتدای دوره تعدیل ‌شده' : 'accumulated_profit_beginning_of_adjusted_period' ,
                              'سود (زیان) خالص هر سهم– ریال' : 'net_profit_per_share_(rail)' ,
                              'فروش خالص' : 'net_sales' , 
                              'بهای تمام شده فروش' : 'cost_of_sales' ,
                              'هزینه های اداری, عمومی و فروش' : 'selling_general_administrative_expenses' ,
                              'سایر درآمدها (هزینه های) عملیاتی' : 'other_operating_income_and_expenses' ,
                              'جمع هزینه ها' : 'total_expenses' ,
                              'هزینه های مالی' : 'financial_cost' ,
                              'خالص سایر درآمدها و هزینه های غیرعملیاتی' : 'net_other_operating_income_and_expenses' ,
                              'سود (زیان) خالص عملیات در حال تداوم قبل از مالیات' : 'profit_operations_in_progress_before_tax' ,
                              'سود (زیان) عملیات متوقف شده پس از اثر مالیاتی' : 'profit_stopped_operations_after_tax_effect' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات در حال تداوم - عملیاتی' : 'profit_per_share_due_to_(operating)_operations_in_progress' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات در حال تداوم - غیرعملیاتی' : 'profit_per_share_due_to_(non_operating)_operations_in_progress' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات متوقف شده' : 'profit_per_share_due_to_stopped_operations' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات در حال تداوم - عملیاتی' : 'reduced_profit_per_share_due_to_(operating)_operations_in_progress' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات در حال تداوم - غیرعملیاتی' : 'reduced_profit_per_share_due_to_(non_operating)_operations_in_progress' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات متوقف شده' : 'reduced_profit_per_share_due_to_stopped_operations' ,
                              'گردش حساب سود (زيان) انباشته' : 'accumulated_profit_account_turnover' ,
                              'سود (زیان) انباشته ابتدای دوره تعدیل شده' : 'accumulated_profit_beginning_of_adjusted_period' ,
                              'تغییرات در سود انباشته' : 'changes_in_accumulated_profits' ,
                              'سود سهام مصوب' : 'approved_dividend' ,
                              'اندوخته قانونی' : 'legal_reserves' ,
                              'سایر اندوخته ها' : 'other_reserves' ,
                              'جمع تغییرات در سود انباشته' : 'total_changes_in_accumulated_profits' ,
                              'سود (زیان) انباشته پایان دوره' : 'accumulated_profit_end_of_period' , 
                              'سود هر سهم پس از کسر مالیات' : 'profit_per_share_after_tax' ,
                              'فروش و درآمد ارائه خدمات' : 'sales_and_revenue' ,
                              'بهای تمام شده کالای فروش رفته' : 'cost_of_goods_sold' ,
                              'سود (زيان) ناخالص' : 'gross_profit' ,
                              'هزینه های عمومی, اداری و تشکیلاتی' : 'selling_general_administrative_expenses' ,
                              'خالص سایر درآمدها (هزینه ها) ی عملیاتی' : 'net_other_operating_income_and_expenses' ,
                              'درآمد حاصل از سرمایه گذاریها' : 'investments_revenue' ,
                              'خالص درآمد (هزینه) های متفرقه' : 'net_other_income_and_expenses' , 
                              'سود (زیان) قبل از اقلام غیر مترقبه, اثرات انباشته تغییر در اصول و روشهای حسابداری' : 'profit_befor_unexpected_items_changes_in_accounting_principles' ,
                              'اقلام غیر مترقبه, اثرات انباشته تغییر در اصول و روشهای حسابداری و مالیات' : 'unexpected_items_changes_in_accounting_principles' ,
                              'سود (زیان) قبل از کسر مالیات' : 'profit_befor_tax' ,
                              'مالیات' : 'tax' ,
                              'سود (زیان) خالص پس از کسر مالیات' : 'net_profit_after_tax' ,
                              'سود (زیان) انباشته در ابتدای سال (دوره) مالی' : 'accumulated_profit_beginning_of_period' ,
                              'سود (زیان) انباشته در ابتدای سال / دوره مالی - تعدیل شده' : 'accumulated_profit_beginning_of_adjusted_period' ,
                              'اندوخته طرح و توسعه' : 'r_and_d_rederves' ,
                              'کاهش (افزایش) سرمایه از محل زیان(سود) انباشته' : 'capital_decrease_and_increase_from_accumulated_profit' ,
                              'سود سهام مصوب مجمع' : 'approved_dividend' ,
                              'سود انباشته در پایان دوره مالی' : 'accumulated_profit_end_of_period' ,
                              'درآمدها' : 'revenues' ,
                              'درآمدهای مشاع' : 'joint_income' ,
                              'سود و وجه التزام تسهیلات اعطایی' : 'loan_interests' ,
                              'سود (زیان) حاصل از سرمایه‌گذاری‌ها و سپرده‌گذاری‌ها' : 'profit_of_investments_and_deposits' ,
                              'جمع درآمدهای مشاع' : 'total_joint_income' ,
                              'سود علی‌الحساب سپرده‌های سرمایه‌گذاری' : 'interest _on _investment _deposits' ,
                              'تفاوت سود قطعی و علی‌الحساب سپرده‌های سرمایه‌گذاری' : 'difference_definite_profit_and_profit_on_account' ,
                              'سهم سود سپرده‌گذاران' : 'depositors_profit_share' ,
                              'سهم بانک از درآمدهای مشاع' : 'bank_share_of_joint_incomes' ,
                              'درآمدهای غیرمشاع' : 'non_joint_income' , 
                              'سود و وجه التزام فعالیت‌های غیرمشاع' : 'interests _on _non_joint_activity' ,
                              'درآمد کارمزد' : 'fee_income' ,
                              'نتیجه مبادلات ارزی' : 'currency_exchanges' ,
                              'سایر درآمدها' : 'other_income' ,
                              'جمع درآمدهای غیرمشاع' : 'total_non_joint_income' ,
                              'جمع درآمدها' : 'total_income' ,
                              'هزینه‌ها' : 'expenses' ,
                              'هزینه‌های کارکنان' : 'staff_expenses' ,
                              'سایر هزینه‌های اجرایی' : 'other_executive_costs' , 
                              'هزینه مطالبات مشکوک‌الوصول' : 'suspicious_claims_costs' ,
                              'هزینه کارمزد' : 'fee_costs' ,
                              'جمع هزینه‌ها' : 'total_costs' ,
                              'سود (زیان) پایه هر سهم ناشی از عملیات در حال تداوم' : 'profit_per_share_due_to_operations_in_progress' ,
                              'سود (زیان) تقلیل یافته هر سهم ناشی از عملیات در حال تداوم' : 'reduced_profit_per_share_due_to_operations_in_progress' ,
                              'سود تسهیلات اعطایی -مشاع' : 'loan_interests_(joint)' ,
                              'سود (زیان) حاصل از سرمایه گذاری ها و سپرده گذاری ها' : 'profit_of_investments_and_deposits' ,
                              'سود علی الحساب سپرده های سرمایه گذاری' : 'interest _on _investment _deposits' ,
                              'تفاوت سود قطعی و علی الحساب سپرده های سرمایه گذاری' : 'difference_definite_profit_and_profit_on_account' ,
                              'سهم سود سپرده گذاران' : 'depositors_profit_share' ,
                              'سهم بانک از درآمدهای مشاع (شامل حق الوکاله)' : 'bank_share_of_joint_incomes' ,
                              'سود تسهیلات اعطایی - غیرمشاع' : 'loan_interests_(non_joint)' ,
                              'هزینه ها:' : 'expenses' ,
                              'هزینه های اداری و عمومی' : 'general_and_administrative_expenses' ,
                              'هزینه مطالبات مشکوک الوصول' : 'suspicious_claims_costs' ,
                              'سایر هزینه ها' : 'other_expenses' , 
                              'سود (زیان) قبل از مالیات' : 'profit_befor_tax' ,
                              'سود (زیان)تقلیل یافته هر سهم ناشی از عملیات در حال تداوم - غیرعملیاتی' : 'reduced_profit_per_share_due_to_(non_operating)_operations_in_progress' ,
                              'سود (زیان) انباشته‌ ابتداي‌ دوره' : 'accumulated_profit_beginning_of_period' ,
                              'تعديلات‌ سنواتي‌' : 'annual_adjustments' ,
                              'انتقال‌ از سایر اقلام حقوق صاحبان سهام' : 'transfer_of_other_equity_items' ,
                              'اندوخته‌ قانوني‌' : 'legal_reserve' , 
                              'سایر اندوخته‌ها' : 'other_reserves' ,
                              'سود حاصل از سرمایه گذاری' : 'profit_of_investments' ,
                              'سود حاصل از فروش سرمایه گذاری' : 'profti_sales _of_investments' ,
                              'سود حاصل از سایر فعالیتها' : 'other_activities_profit' ,
                              'سود (زیان) خالص هر سهم–ریال' : 'net_profit_per_share_(rial)' ,
                              'فروش' : 'sales' ,
                              'درآمد حاصل از سایر فعالیتها' : 'other_activities_income' ,
                              'کاهش(افزایش) سرمایه از محل زیان(سود) انباشته' : 'capital_decrease_and_increase_from_accumulated_profit' ,
                              'درآمد حاصل از عملیات لیزینگ' : 'leasing_operations_income' ,
                              'هزینه تامین منابع مالی عملیات لیزینگ' : 'leasing_operations_financial_expenses' ,
                              'اقلام غیر مترقبه، اثرات انباشته تغییر در اصول و روشهای حسابداری و مالیات' : 'unexpected_items_changes_in_accounting_principles' ,
                              'عملیات در حال تداوم:' : 'operations_in_progress' ,
                              'بهاى تمام شده درآمدهای عملیاتی' : 'cost_of_operating_income' ,
                              'هزينه‌هاى فروش، ادارى و عمومى' : 'selling_general_administrative_expenses' ,
                              'هزینه کاهش ارزش دریافتنی‌ها (هزینه استثنایی)' : 'cost_of_decrease_in_ value_of_receivables' ,
                              'ساير درآمدها':'other_revenues' ,
                              'سایر هزینه‌ها' : 'other_expenses' ,
                              'سود (زيان) عملياتي' : 'operating_profit' ,
                              'هزينه‌هاى مالى' : 'financial_costs' ,
                              'سود (زيان) عمليات در حال تداوم قبل از ماليات' : 'profit_operations_in_progress_before_tax' ,
                              'هزینه مالیات بر درآمد:' : 'income_tax_expense' ,
                              'سال جاری' : 'current_year' ,
                              'سال‌های قبل' : 'last_year' , 
                              'سود (زيان) خالص عمليات در حال تداوم' : 'net_profit_operations_in_progress' ,
                              'عملیات متوقف شده:' : 'stopped_operation' ,
                              'سود (زیان) خالص عملیات متوقف شده' : 'net_profit_stopped_operations' ,
                              'سود (زيان) خالص' : 'net_profit' ,
                              'سود (زيان) پايه هر سهم' : 'profit_per_share' ,
                              'عملیاتی (ریال)' : 'operating_(rial)' ,
                              'غیرعملیاتی (ریال)' : 'non_operating_rial' ,
                              'ناشی از عملیات در حال تداوم' : 'due_to_operations_in_progress' ,
                              'ناشی از عملیات متوقف شده' : 'due_to_stopped_operations' ,
                              'سود ناخالص' : 'gross_profit' ,
                              'سود عملياتى' : 'operating_profit' ,
                              'سود عملیات در حال تداوم قبل از ماليات' : 'profit_operations_in_progress_before_tax' ,
                              'سود خالص عملیات در حال تداوم' : 'net_profit_operations_in_progress' ,
                              'سود خالص' : 'net_profit' ,
                              'سود پایه هر سهم:' : 'profit_per_share' ,
                              'درآمد تسهيلات اعطايي و سپرده گذاری و اوراق بدهی' : 'income_by_loans_deposits_bonds' ,
                              'هزينه سود سپرده‌ها' : 'cost_of_deposits_interest' ,
                              'خالص درآمد تسهیلات و سپرده گذاری' : 'net_loans_and_deposits_revenue' ,
                              'هزينه کارمزد' : 'fee_costs' ,
                              'خالص درآمد کارمزد' : 'net_fee_income' ,
                              'خالص سود (زیان) سرمایه گذاری‌ها' : 'net_profit_of_investments' ,
                              'خالص سود (زيان) مبادلات و معاملات ارزي' : 'net_profit_of_currency_exchanges' ,
                              'ساير درآمدها و هزینه های عملياتي' : 'other_operating_income_and_expenses' ,
                              'جمع درآمدهاي عملياتي' : 'total_operating_income' ,
                              'خالص ساير درآمدها و هزینه‌ها' : 'net_other_income_and_expenses' ,
                              'هزينه‌هاي اداري و عمومي' : 'general_administrative_expenses' ,
                              'هزينه مطالبات مشکوک الوصول' : 'suspicious_claims_costs' ,
                              'هزينه‌هاي مالي' : 'financial_costs' ,
                              'هزينه استهلاک' : 'depreciation_cost' ,
                              'سود(زیان) عملیات در حال تداوم قبل از مالیات' : 'profit_operations_in_progress_before_tax' ,
                              'ماليات بر درآمد سال جاری' : 'current_year_income_tax' ,
                              'ماليات بر درآمد سال های قبل' : 'last_year_income_tax' ,
                              'سود (زيان) خالص عملیات در حال تداوم' : 'profit_operations_in_progress' ,
                              'سود(زیان) خالص عملیات متوقف شده' : 'net_profit_stopped_operations' ,
                              'سود(زیان) خالص' : 'net_profit' ,
                              'سود (زیان)پایه هر سهم (ريال)' : 'profit_per_share' ,
                              'عملياتي (ريال)' : 'operating' ,
                              'غيرعملياتي(ريال)' : 'non_operating' ,
                              'ناشی از عملیات در حال تداوم(ریال)' : 'due_to_operations_in_progress' ,
                              'ناشي از عمليات متوقف شده(ريال)' : 'due_to_stopped_operations' ,
                              'سود(زیان) پایه هر سهم (ریال)' : 'profit_per_share' ,
                              'غیرعملیاتی(ریال)' : 'non_operating' ,
                              'سود علی الحساب سپرده های سرمایه گذاری' : 'interest _on _investment _deposits' ,
                              'پاداش هیات مدیره' : 'board_rewards' ,
                              'ناشی از عملیات متوقف شده(ریال)' : 'due_to_stopped_operations'})

    df = y.iloc[:y[y['description']=='capital'].index.tolist()[0]+1]

    return df

# %%
def col_edit_1(t):

    if len(t.columns) == 16 :
        t.insert(loc= 10, column= "national_code", value= list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['shenaseh_meli'])[0])
        t.replace(t['company_name'].values, list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad'] ]['company_name_English'])[0], inplace=True)
        t.replace(t['nemad'].values, list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['en'])[0] , inplace=True)


        t.replace(t['table_title'].values, "balance_sheet" , inplace=True)

        if t.loc[0,'title'].find('دوره ۶ ماهه') != -1:
            t.insert(loc=13 , column = 'reported_period' , value = "6_months_interim")
        elif t.loc[0,'title'].find('دوره ۳ ماهه') != -1:
            t.insert(loc=13 , column='reported_period' , value= "3_months_interim")
        elif t.loc[0,'title'].find('دوره ۹ ماهه') != -1:
            t.insert(loc=13 , column='reported_period' , value= "9_months_interim")
        else:
            t.insert(loc=13 , column='reported_period' , value= "12_months_interim")
            
    elif len(t.columns) == 13 :
        
        t.insert(loc= 7, column= "national_code", value= list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['shenaseh_meli'])[0])
        t.replace(t['company_name'].values, list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad'] ]['company_name_English'])[0], inplace=True)
        t.replace(t['nemad'].values, list(nemad.loc[nemad['stock_name']== t.loc[0 , 'nemad']]['en'])[0] , inplace=True)

        t.replace(t['table_title'].values, "balance_sheet" , inplace=True)

        if t.loc[0,'title'].find('دوره ۶ ماهه') != -1:
            t.insert(loc=10 , column = 'reported_period' , value = "6_months_interim")
        elif t.loc[0,'title'].find('دوره ۳ ماهه') != -1:
            t.insert(loc=10 , column='reported_period' , value= "3_months_interim")
        elif t.loc[0,'title'].find('دوره ۹ ماهه') != -1:
            t.insert(loc=10 , column='reported_period' , value= "9_months_interim")
        else:
            t.insert(loc=10 , column='reported_period' , value= "12_months_interim")

    return t

# %%
def to_g(x):
    x=jdatetime.datetime(int(x.split('-')[0]) , int(x.split('-')[1]),int(x.split('-')[2])).togregorian()
    return x

# %%
def time_edit_1(r):
    if len(r.columns) == 18 :
        r.insert(loc=14 , column="reported_date_j" , value =re.sub("\/" , "-" , digits.fa_to_en(re.search(r'(\d+/\d+/\d+)', r.loc[0 , 'title']).group(1))) )
        r.insert(loc=15 , column="reported_date_m" , value= r['reported_date_j'].apply(lambda x:to_g(x)))
    
    elif len(r.columns) == 15 :
        r.insert(loc=11 , column="reported_date_j" , value =re.sub("\/" , "-" , digits.fa_to_en(re.search(r'(\d+/\d+/\d+)', r.loc[0 , 'title']).group(1))) )
        r.insert(loc=12 , column="reported_date_m" , value= r['reported_date_j'].apply(lambda x:to_g(x)))
    return r

# %%
def char_edit_1(ch):
    
    if len(ch.columns) == 20 :

        if ch.loc[0,'title'].find('حسابرسی شده') != -1:
            ch.insert(loc=16 , column='reported_audit_status' , value= "audited")
        elif ch.loc[0,'title'].find('حسابرسی نشده') != -1:
            ch.insert(loc=16 , column='reported_audit_status' , value= "not_audited")
        else:
            ch.insert(loc=16 , column='reported_audit_status' , value= "unknown")

        if ch.loc[0 , 'title'].find('اصلاحیه') != -1:
            ch.insert(loc=17 , column= 'is_corrected' , value='1')
        else:
            ch.insert(loc=17 , column= 'is_corrected' , value='0')


        ch.drop(columns=['title'] , inplace=True)

        ch[ch.columns[4]]= ch[ch.columns[4]].apply(lambda x: digits.fa_to_en(x))
        ch[ch.columns[7]]= ch[ch.columns[7]].apply(lambda x: digits.fa_to_en(x))
        ch[ch.columns[1]]= ch[ch.columns[1]].apply(lambda x: digits.fa_to_en(x))

        ch['publish_time']= ch['publish_time'].apply(lambda x: digits.fa_to_en(x))
        ch['send_time']= ch['send_time'].apply(lambda x: digits.fa_to_en(x))

        
        
    if len(ch.columns) == 17 : 

        if ch.loc[0,'title'].find('حسابرسی شده') != -1:
            ch.insert(loc=13 , column='reported_audit_status' , value= "audited")
        elif ch.loc[0,'title'].find('حسابرسی نشده') != -1:
            ch.insert(loc=13 , column='reported_audit_status' , value= "not_audited")
        else:
            ch.insert(loc=13 , column='reported_audit_status' , value= "unknown")

        if ch.loc[0 , 'title'].find('اصلاحیه') != -1:
            ch.insert(loc=14 , column= 'is_corrected' , value='1')
        else:
            ch.insert(loc=14 , column= 'is_corrected' , value='0')


        ch.drop(columns=['title'] , inplace=True)


        ch[ch.columns[4]]= ch[ch.columns[4]].apply(lambda x: digits.fa_to_en(x))
        ch[ch.columns[1]]= ch[ch.columns[1]].apply(lambda x: digits.fa_to_en(x))
        
        ch['publish_time']= ch['publish_time'].apply(lambda x: digits.fa_to_en(x))
        ch['send_time']= ch['send_time'].apply(lambda x: digits.fa_to_en(x))



    return ch

# %%
def x_concat_1(table):
    
    if len(table.columns) == 21 :

        table_1= table.filter(['description' , table.columns[1] , 'date_1' , 'audit_status_1' , 'national_code' , 'nemad' , 'company_name' ,
                         'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'send_time' , 'publish_time' , 'table_title'])
        table_2= table.filter(['description' , table.columns[4] , 'date_2' , 'audit_status_2' , 'national_code' , 'nemad' , 'company_name' ,
                         'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'send_time' , 'publish_time' , 'table_title'])
        table_3= table.filter(['description' , table.columns[7] , 'date_3' , 'audit_status_3' , 'national_code' , 'nemad' , 'company_name' ,
                         'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'send_time' , 'publish_time' , 'table_title'])

        table_1.rename(columns={table.columns[1]:'value' , 'date_1':'date' , 'audit_status_1':'audit_status'} , inplace=True)
        table_2.rename(columns={table.columns[4]:'value' , 'date_2':'date' , 'audit_status_2':'audit_status'} , inplace=True)
        table_3.rename(columns={table.columns[7]:'value' , 'date_3':'date' , 'audit_status_3':'audit_status'} , inplace=True)

        data_final= pd.concat([table_1 , table_2 , table_3] , ignore_index=True)
        

    elif len(table.columns) == 18 :

        table_1= table.filter(['description' , table.columns[1] , 'date_1' , 'audit_status_1' , 'national_code' , 'nemad' , 'company_name' ,
                         'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'send_time' , 'publish_time' , 'table_title'])
        table_2= table.filter(['description' , table.columns[4] , 'date_2' , 'audit_status_2' , 'national_code' , 'nemad' , 'company_name' ,
                         'reported_period' , 'reported_date_j' , 'reported_date_m' , 'reported_audit_status' , 'is_corrected' , 'send_time' , 'publish_time' , 'table_title'])

        table_1.rename(columns={table.columns[1]:'value' , 'date_1':'date' , 'audit_status_1':'audit_status'} , inplace=True)
        table_2.rename(columns={table.columns[4]:'value' , 'date_2':'date' , 'audit_status_2':'audit_status'} , inplace=True)
        
        data_final= pd.concat([table_1 , table_2] , ignore_index=True)

    return data_final

# %%
def total_value_1(p):
    
    p.drop(p[p.description.str.contains("شرح")].index , inplace=True)
    p.drop(p[p.description.str.contains("/")].index , inplace=True)
    p.drop(p[p.value.str.contains("/")].index , inplace=True)

    p.insert(loc=4 , column='is_total_value' , value= '0')

    index=p[p.description.str.contains('net_profit')].index
    index=index.to_list()
    p.loc[index,'is_total_value']=1

    index=p[p.description.str.contains('gross_profit')].index
    index=index.to_list()
    p.loc[index,'is_total_value']=1

    if p.loc[0 , 'is_corrected']=='1':
        k='_correction_'
    else:
        k='_'

    directory = r"C:\Users\cmos\Desktop\Codal_ProfitLoss\export\export part 2"
    file_name = list(nemad.loc[nemad['en'] == p.loc[0 , 'nemad']]['en'])[0]
    path_join = os.path.join(directory, file_name)
    try:
        os.mkdir(path_join)
    except :
        print('Cant')
        
    p.to_excel(f"{path_join}/{p.iloc[0,5]}_{p.iloc[0,6]}_{p.iloc[0,9]}_{p.iloc[0,11]}{k}profit_loss.xlsx" , index=False)

# %%
def final(path):
    total_value_1(x_concat_1(char_edit_1(time_edit_1(col_edit_1(label_trans_1(clean_drop_1(pd.read_excel(path))))))))

# %%
def final_2(path):
    total_value_1(x_concat_1(char_edit_1(time_edit_1(col_edit_1(label_trans_1(clean_drop_2(pd.read_excel(path))))))))

# %%
errorlist_1 = []
errorlist_2 = []
errorlist_3 = []
errorlist_4 = []
errorlist_5 = []
errorlist_6 = []
errorlist_7 = []
errorlist_8 = []
errorlist_9 = []
errorlist_10 = []
errorlist_11 = []
errorlist_12 = []
errorlist_13 = []
errorlist_14 = []
errorlist_15 = []
errorlist_16 = []
errorlist_17 = []
errorlist_18 = []
errorlist_19 = []
errorlist_20 = []
errorlist_21 = []
errorlist_22 = []







def export(kk):
    l = pd.read_excel(kk)
    a = l.shape
    
    if a == (39, 13):
        try:
            pd.Series(kk).apply(final)
        except:
            errorlist_1.append(kk)
            
    if a == (53, 13):
        try:
            pd.Series(kk).apply(final)
        except:
            errorlist_2.append(kk)
            
    if a == (56, 13):
        try:
            pd.Series(kk).apply(final)
        except:
            errorlist_3.append(kk)
            
    if a == (64, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_4.append(kk)
                        
    if a == (64, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_5.append(kk)
                                    
    if a == (60, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_6.append(kk)
                                        
    if a == (60, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_7.append(kk)
                                            
    if a == (59, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_8.append(kk)
                                            
    if a == (59, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_9.append(kk)
                                                        
    if a == (47, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_10.append(kk)
                                                        
    if a == (46, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_11.append(kk)
                                                             
    if a == (45, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_12.append(kk)
            
    if a == (45, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_13.append(kk)
                                                                 
    if a == (64, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_14.append(kk)
                                                                                          
    if a == (64, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_15.append(kk)
                                                                                              
    if a == (68, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_16.append(kk)
                                                                                                                                                                                          
    if a == (68, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_17.append(kk)
                                                                                                    
    if a == (71, 13):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_18.append(kk)                                                                
                                                                                                   
    if a == (71, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_19.append(kk)
            
    if a == (42, 13):
        try:
            pd.Series(kk).apply(final)
        except:
            errorlist_20.append(kk) 
                
    if a == (52, 13):
        try:
            pd.Series(kk).apply(final)
        except:
            errorlist_21.append(kk)
     
    if a == (46, 12):
        try:
            pd.Series(kk).apply(final_2)
        except:
            errorlist_22.append(kk)

# %%
pd.Series(profit_loss).apply(export)
# Out:
# Cant
# Cant
# Cant
# Cant
# False
# False
# Cant
# Cant
# Cant
# Cant
# False
# False
# Cant
# Cant
# Cant
# False
# False
# Cant
# False
# False
# Cant
# False
# False
# Cant
# None
# False
# Cant
# Cant
# Cant
# Cant
# Cant
# Cant
# Cant
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# 16    None
# 17    None
# 18    None
# 19    None
# 20    None
# 21    None
# dtype: object

# %%
errorlist_1 = []

# %%
errorlist_2 = []

# %%
errorlist_3 = []

# %%
errorlist_4 = []

# %%
errorlist_5 = []

# %%
errorlist_6 = []

# %%
errorlist_7 = []

# %%
errorlist_8 = []

# %%
errorlist_9 = []

# %%
errorlist_10 = []

# %%
errorlist_11 = []

# %%
errorlist_12 = []

# %%
errorlist_13 = []

# %%
errorlist_14 = []

# %%
errorlist_15 = []

# %%
errorlist_16 = []

# %%
errorlist_17 = []

# %%
errorlist_18 = []

# %%
errorlist_19 = []

# %%
errorlist_20 = []

# %%
errorlist_21 = []

# %%
errorlist_22 = []
